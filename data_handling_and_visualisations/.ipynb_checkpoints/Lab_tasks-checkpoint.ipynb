# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import sys # enables us to use sys.stdout - showing info in readable form

# %%
iris = pd.read_csv('iris.csv')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# write the iris DF to a new csv file
df_iris = iris
df_iris.to_csv('new_df_iris.csv')

# %%
# view our iris DF as csv
# pd.read_fwf('new_df_iris.csv')  
iris.to_csv(sys.stdout, sep=' ')
# Out:
#  sepal_length sepal_width petal_length petal_width species
# 0 5.1 3.5 1.4 0.2 setosa
# 1 4.9 3.0 1.4 0.2 setosa
# 2 4.7 3.2 1.3 0.2 setosa
# 3 4.6 3.1 1.5 0.2 setosa
# 4 5.0 3.6 1.4 0.2 setosa
# 5 5.4 3.9 1.7 0.4 setosa
# 6 4.6 3.4 1.4 0.3 setosa
# 7 5.0 3.4 1.5 0.2 setosa
# 8 4.4 2.9 1.4 0.2 setosa
# 9 4.9 3.1 1.5 0.1 setosa
# 10 5.4 3.7 1.5 0.2 setosa
# 11 4.8 3.4 1.6 0.2 setosa
# 12 4.8 3.0 1.4 0.1 setosa
# 13 4.3 3.0 1.1 0.1 setosa
# 14 5.8 4.0 1.2 0.2 setosa
# 15 5.7 4.4 1.5 0.4 setosa
# 16 5.4 3.9 1.3 0.4 setosa
# 17 5.1 3.5 1.4 0.3 setosa
# 18 5.7 3.8 1.7 0.3 setosa
# 19 5.1 3.8 1.5 0.3 setosa
# 20 5.4 3.4 1.7 0.2 setosa
# 21 5.1 3.7 1.5 0.4 setosa
# 22 4.6 3.6 1.0 0.2 setosa
# 23 5.1 3.3 1.7 0.5 setosa
# 24 4.8 3.4 1.9 0.2 setosa
# 25 5.0 3.0 1.6 0.2 setosa
# 26 5.0 3.4 1.6 0.4 setosa
# 27 5.2 3.5 1.5 0.2 setosa
# 28 5.2 3.4 1.4 0.2 setosa
# 29 4.7 3.2 1.6 0.2 setosa
# 30 4.8 3.1 1.6 0.2 setosa
# 31 5.4 3.4 1.5 0.4 setosa
# 32 5.2 4.1 1.5 0.1 setosa
# ...

# %%
# view the data grouped by species name
grouped_iris = iris.groupby('species')
grouped_iris.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 0             5.1          3.5           1.4          0.2      setosa
# 1             4.9          3.0           1.4          0.2      setosa
# 2             4.7          3.2           1.3          0.2      setosa
# 3             4.6          3.1           1.5          0.2      setosa
# 4             5.0          3.6           1.4          0.2      setosa
# 50            7.0          3.2           4.7          1.4  versicolor
# 51            6.4          3.2           4.5          1.5  versicolor
# 52            6.9          3.1           4.9          1.5  versicolor
# 53            5.5          2.3           4.0          1.3  versicolor
# 54            6.5          2.8           4.6          1.5  versicolor
# 100           6.3          3.3           6.0          2.5   virginica
# 101           5.8          2.7           5.1          1.9   virginica
# ...

# %%
# iterate through each group of species data and print the records (python logic)

# print(iris.to_string())

# row = next(iris.iterrows())[0]
# print(row)

#for index, row in iris.iterrows():
#    print(row['species'], row['sepal_length'], row['sepal_width'], row['petal_length'], row['petal_width'])

for i in grouped_iris:
    print(i)
# Out:
# ('setosa',     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
grouped_iris.describe()
# Out:
#            sepal_length                                              \
#                   count   mean       std  min    25%  50%  75%  max
# species
# setosa             50.0  5.006  0.352490  4.3  4.800  5.0  5.2  5.8
# versicolor         50.0  5.936  0.516171  4.9  5.600  5.9  6.3  7.0
# virginica          50.0  6.588  0.635880  4.9  6.225  6.5  6.9  7.9
#
#            sepal_width         ... petal_length      petal_width         \
#                  count   mean  ...          75%  max       count   mean
# species                        ...
# setosa            50.0  3.418  ...        1.575  1.9        50.0  0.244
# versicolor        50.0  2.770  ...        4.600  5.1        50.0  1.326
# virginica         50.0  2.974  ...        5.875  6.9        50.0  2.026
#
#
#                  std  min  25%  50%  75%  max
# species
# setosa      0.107210  0.1  0.2  0.2  0.3  0.6
# versicolor  0.197753  1.0  1.2  1.3  1.5  1.8
# virginica   0.274650  1.4  1.8  2.0  2.3  2.5
#
# ...

# %%
# Add a rank column to the iris DataFrame, ranking the petal length in an ascending order
iris['rank'] = iris['petal_length'].rank(method='min')
print(iris)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species   rank
# 0             5.1          3.5           1.4          0.2     setosa   12.0
# 1             4.9          3.0           1.4          0.2     setosa   12.0
# 2             4.7          3.2           1.3          0.2     setosa    5.0
# 3             4.6          3.1           1.5          0.2     setosa   24.0
# 4             5.0          3.6           1.4          0.2     setosa   12.0
# ..            ...          ...           ...          ...        ...    ...
# 145           6.7          3.0           5.2          2.3  virginica  117.0
# 146           6.3          2.5           5.0          1.9  virginica  105.0
# 147           6.5          3.0           5.2          2.0  virginica  117.0
# 148           6.2          3.4           5.4          2.3  virginica  121.0
# 149           5.9          3.0           5.1          1.8  virginica  109.0
#
# [150 rows x 6 columns]

# %%
# Find the mean of each column for each species
grouped_iris.mean()
grouped_iris

# %%
# Create a new DataFrame for each of the species separately - should have 3 in total, make sure each index starts at 0
setosa_df = iris[iris['species'] == 'setosa'].reset_index(drop=True)
versicolor_df = iris[iris['species'] == 'versicolor'].reset_index(drop=True)
virginica_df = iris[iris['species'] == 'virginica'].reset_index(drop=True)

print(setosa_df.head())
print(versicolor_df.head())
print(virginica_df.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  rank
# 0           5.1          3.5           1.4          0.2  setosa  12.0
# 1           4.9          3.0           1.4          0.2  setosa  12.0
# 2           4.7          3.2           1.3          0.2  setosa   5.0
# 3           4.6          3.1           1.5          0.2  setosa  24.0
# 4           5.0          3.6           1.4          0.2  setosa  12.0
#    sepal_length  sepal_width  petal_length  petal_width     species   rank
# 0           7.0          3.2           4.7          1.4  versicolor   91.0
# 1           6.4          3.2           4.5          1.5  versicolor   80.0
# 2           6.9          3.1           4.9          1.5  versicolor  100.0
# 3           5.5          2.3           4.0          1.3  versicolor   62.0
# 4           6.5          2.8           4.6          1.5  versicolor   88.0
#    sepal_length  sepal_width  petal_length  petal_width    species   rank
# ...

# %%
# Create two final DataFrames: One for the Sepal information, and one for the Petal information.
# This should be done on the whole dataset so that in each DataFrame we have information about all three species

sepal_df = iris[['sepal_length','sepal_width','species']].copy()
print(sepal_df)

petal_df = iris[['petal_length','petal_width','species']].copy()
print(petal_df)
# Out:
#      sepal_length  sepal_width    species
# 0             5.1          3.5     setosa
# 1             4.9          3.0     setosa
# 2             4.7          3.2     setosa
# 3             4.6          3.1     setosa
# 4             5.0          3.6     setosa
# ..            ...          ...        ...
# 145           6.7          3.0  virginica
# 146           6.3          2.5  virginica
# 147           6.5          3.0  virginica
# 148           6.2          3.4  virginica
# 149           5.9          3.0  virginica
#
# [150 rows x 3 columns]
#      petal_length  petal_width    species
# 0             1.4          0.2     setosa
# 1             1.4          0.2     setosa
# 2             1.3          0.2     setosa
# 3             1.5          0.2     setosa
# 4             1.4          0.2     setosa
# ..            ...          ...        ...
# 145           5.2          2.3  virginica
# 146           5.0          1.9  virginica
# 147           5.2          2.0  virginica
# ...

# %% [markdown]
# ## JSON Files in Pandas

# %%
# read json to a pandas object ( DF )
iris_json = pd.read_json('iris_dataset_working.json')

# %%
iris_json.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
pd.merge(sepal_df, petal_df, how='inner', right_index=True, left_index=True)
# Out:
#      sepal_length  sepal_width  species_x  petal_length  petal_width  \
# 0             5.1          3.5     setosa           1.4          0.2
# 1             4.9          3.0     setosa           1.4          0.2
# 2             4.7          3.2     setosa           1.3          0.2
# 3             4.6          3.1     setosa           1.5          0.2
# 4             5.0          3.6     setosa           1.4          0.2
# ..            ...          ...        ...           ...          ...
# 145           6.7          3.0  virginica           5.2          2.3
# 146           6.3          2.5  virginica           5.0          1.9
# 147           6.5          3.0  virginica           5.2          2.0
# 148           6.2          3.4  virginica           5.4          2.3
# 149           5.9          3.0  virginica           5.1          1.8
#
#      species_y
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# 145  virginica
# ...

# %%
sepal_df['sepal_id'] = np.arange(150)
petal_df['petal_id'] = np.arange(150)
petal_df
# Out:
#      petal_length  petal_width    species  petal_id
# 0             1.4          0.2     setosa         0
# 1             1.4          0.2     setosa         1
# 2             1.3          0.2     setosa         2
# 3             1.5          0.2     setosa         3
# 4             1.4          0.2     setosa         4
# ..            ...          ...        ...       ...
# 145           5.2          2.3  virginica       145
# 146           5.0          1.9  virginica       146
# 147           5.2          2.0  virginica       147
# 148           5.4          2.3  virginica       148
# 149           5.1          1.8  virginica       149
#
# [150 rows x 4 columns]

# %%
merged_iris = pd.merge(sepal_df, petal_df, how='inner', left_on='sepal_id', right_on='petal_id')
merged_iris
# Out:
#      sepal_length  sepal_width  species_x  sepal_id  petal_length  \
# 0             5.1          3.5     setosa         0           1.4
# 1             4.9          3.0     setosa         1           1.4
# 2             4.7          3.2     setosa         2           1.3
# 3             4.6          3.1     setosa         3           1.5
# 4             5.0          3.6     setosa         4           1.4
# ..            ...          ...        ...       ...           ...
# 145           6.7          3.0  virginica       145           5.2
# 146           6.3          2.5  virginica       146           5.0
# 147           6.5          3.0  virginica       147           5.2
# 148           6.2          3.4  virginica       148           5.4
# 149           5.9          3.0  virginica       149           5.1
#
#      petal_width  species_y  petal_id
# 0            0.2     setosa         0
# 1            0.2     setosa         1
# 2            0.2     setosa         2
# ...

# %%
merged_iris.drop(['species_x','sepal_id','petal_id'], axis=1)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species_y
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
pd.concat([setosa_df, versicolor_df], axis=0)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species  rank
# 0            5.1          3.5           1.4          0.2      setosa  12.0
# 1            4.9          3.0           1.4          0.2      setosa  12.0
# 2            4.7          3.2           1.3          0.2      setosa   5.0
# 3            4.6          3.1           1.5          0.2      setosa  24.0
# 4            5.0          3.6           1.4          0.2      setosa  12.0
# ..           ...          ...           ...          ...         ...   ...
# 45           5.7          3.0           4.2          1.2  versicolor  70.0
# 46           5.7          2.9           4.2          1.3  versicolor  70.0
# 47           6.2          2.9           4.3          1.3  versicolor  74.0
# 48           5.1          2.5           3.0          1.1  versicolor  51.0
# 49           5.7          2.8           4.1          1.3  versicolor  67.0
#
# [100 rows x 6 columns]

# %% [markdown]
# ## Combining Data Frames

# %%
sales1 = pd.DataFrame({'East': [1500, None, 3500, None],
                      'West': [None, 4500, None, 5500],
                      'South': [6500, None, 7500, None]})
sales2 = pd.DataFrame({'East': [1200, 1300, None, 1600, 1800],
                      'West': [None, 5000, 6000, 7000, 8000]})
sales1
# Out:
#      East    West   South
# 0  1500.0     NaN  6500.0
# 1     NaN  4500.0     NaN
# 2  3500.0     NaN  7500.0
# 3     NaN  5500.0     NaN

# %%
sales1.combine_first(sales2)
# Out:
#      East   South    West
# 0  1500.0  6500.0     NaN
# 1  1300.0     NaN  4500.0
# 2  3500.0  7500.0  6000.0
# 3  1600.0     NaN  5500.0
# 4  1800.0     NaN  8000.0

# %% [markdown]
# ## Lab - Aggregations
# Load the titanic dataset in seaborn (it is a sample dataset - load using 'sns.load_dataset('titanic')')
# * Clean the dataset - where are the missing values, can they be filled/need to be dropped? Are there any duplicates?
# * Find the average fare and age for each class
# * Add a new column showing the fare as a percentage of total
# * How many survivors were female compared to male?
# * What interesting insights can you draw?

# %%
import seaborn as sns
titanic = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# Clean the dataset - where are the missing values, can they be filled/need to be dropped? Are there any duplicates?

# titanic = titanic.drop(columns='deck')

#titanic['age'] = titanic['age'].fillna((titanic['age'].mean()).round())
# print(titanic)


#titanic = titanic.drop_duplicates()
#titanic.duplicated()

titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 888         0       3  female  30.0      1      2  23.4500        S  Third
# 889         1       1    male  26.0      0      0  30.0000        C  First
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
# Find the average fare and age for each class

# titanic_first = titanic[titanic['class'] == 'First']
# titanic_first_average_fare_age = titanic_first[['fare','age']].mean()
# print(titanic_first_average_fare_age)

titanic_average_fare_age = titanic.groupby('class')[['fare','age']].mean()
titanic_average_fare_age
# Out:
# C:\Users\usama\AppData\Local\Temp\ipykernel_2136\4030841708.py:7: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   titanic_average_fare_age = titanic.groupby('class')[['fare','age']].mean()
#              fare        age
# class
# First   84.487812  37.184206
# Second  21.835404  29.902000
# Third   13.726868  25.965338

# %%
# Add a new column showing the fare as a percentage of total

titanic_fare_total = titanic['fare'].sum()

titanic['fare percentage'] = (titanic['fare'] / titanic_fare_total) * 100

titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 888         0       3  female  30.0      1      2  23.4500        S  Third
# 889         1       1    male  26.0      0      0  30.0000        C  First
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male  embark_town alive  alone  fare percentage
# ...

# %%
# How many survivors were female compared to male?

titanic['fem
# Out:
#   Cell In[280], line 3
#     titanic['sex'] == female count()
#                              ^
# SyntaxError: invalid syntax

# %%
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights_piv = flights.pivot(index='year', columns='month', values='passengers')
flights_piv.head()
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201

# %%
# stacking - rearranging pivoted data 
# which creates a multi-level index
flights_stack = flights_piv.stack()
flights_stack
# Out:
# year  month
# 1949  Jan      112
#       Feb      118
#       Mar      132
#       Apr      129
#       May      121
#               ...
# 1960  Aug      606
#       Sep      508
#       Oct      461
#       Nov      390
#       Dec      432
# Length: 144, dtype: int64

# %%
flights_stack.unstack()
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201
# 1954   204  188  235  227  234  264  302  293  259  229  203  229
# 1955   242  233  267  269  270  315  364  347  312  274  237  278
# 1956   284  277  317  313  318  374  413  405  355  306  271  306
# 1957   315  301  356  348  355  422  465  467  404  347  305  336
# 1958   340  318  362  348  363  435  491  505  404  359  310  337
# 1959   360  342  406  396  420  472  548  559  463  407  362  405
# 1960   417  391  419  461  472  535  622  606  508  461  390  432

# %%
# crosstabulation - compute a frequency table of 2 or more factors
# (specify a result other than frequency, using aggregate functions passed in)

pd.crosstab(iris.species, iris.petal_width)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 # crosstabulation - compute a frequency table of 2 or more factors
#       2 # (specify a result other than frequency, using aggregate functions passed in)
# ----> 4 pd.crosstab(iris.species, iris.petal_width)
#
# NameError: name 'pd' is not defined
